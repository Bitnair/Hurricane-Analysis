# %%
# names of hurricanes
names = ['Cuba I', 'San Felipe II Okeechobee', 'Bahamas', 'Cuba II', 'CubaBrownsville', 'Tampico', 'Labor Day', 'New England', 'Carol', 'Janet', 'Carla', 'Hattie', 'Beulah', 'Camille', 'Edith', 'Anita', 'David', 'Allen', 'Gilbert', 'Hugo', 'Andrew', 'Mitch', 'Isabel', 'Ivan', 'Emily', 'Katrina', 'Rita', 'Wilma', 'Dean', 'Felix', 'Matthew', 'Irma', 'Maria', 'Michael']

# months of hurricanes
months = ['October', 'September', 'September', 'November', 'August', 'September', 'September', 'September', 'September', 'September', 'September', 'October', 'September', 'August', 'September', 'September', 'August', 'August', 'September', 'September', 'August', 'October', 'September', 'September', 'July', 'August', 'September', 'October', 'August', 'September', 'October', 'September', 'September', 'October']

# years of hurricanes
years = [1924, 1928, 1932, 1932, 1933, 1933, 1935, 1938, 1953, 1955, 1961, 1961, 1967, 1969, 1971, 1977, 1979, 1980, 1988, 1989, 1992, 1998, 2003, 2004, 2005, 2005, 2005, 2005, 2007, 2007, 2016, 2017, 2017, 2018]

# maximum sustained winds (mph) of hurricanes
max_sustained_winds = [165, 160, 160, 175, 160, 160, 185, 160, 160, 175, 175, 160, 160, 175, 160, 175, 175, 190, 185, 160, 175, 180, 165, 165, 160, 175, 180, 185, 175, 175, 165, 180, 175, 160]

# areas affected by each hurricane
areas_affected = [['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], ['Lesser Antilles', 'The Bahamas', 'United States East Coast', 'Atlantic Canada'], ['The Bahamas', 'Northeastern United States'], ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], ['Jamaica', 'Yucatn Peninsula'], ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'], ['Southeastern United States', 'Northeastern United States', 'Southwestern Quebec'], ['Bermuda', 'New England', 'Atlantic Canada'], ['Lesser Antilles', 'Central America'], ['Texas', 'Louisiana', 'Midwestern United States'], ['Central America'], ['The Caribbean', 'Mexico', 'Texas'], ['Cuba', 'United States Gulf Coast'], ['The Caribbean', 'Central America', 'Mexico', 'United States Gulf Coast'], ['Mexico'], ['The Caribbean', 'United States East coast'], ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'], ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'], ['The Caribbean', 'United States East Coast'], ['The Bahamas', 'Florida', 'United States Gulf Coast'], ['Central America', 'Yucatn Peninsula', 'South Florida'], ['Greater Antilles', 'Bahamas', 'Eastern United States', 'Ontario'], ['The Caribbean', 'Venezuela', 'United States Gulf Coast'], ['Windward Islands', 'Jamaica', 'Mexico', 'Texas'], ['Bahamas', 'United States Gulf Coast'], ['Cuba', 'United States Gulf Coast'], ['Greater Antilles', 'Central America', 'Florida'], ['The Caribbean', 'Central America'], ['Nicaragua', 'Honduras'], ['Antilles', 'Venezuela', 'Colombia', 'United States East Coast', 'Atlantic Canada'], ['Cape Verde', 'The Caribbean', 'British Virgin Islands', 'U.S. Virgin Islands', 'Cuba', 'Florida'], ['Lesser Antilles', 'Virgin Islands', 'Puerto Rico', 'Dominican Republic', 'Turks and Caicos Islands'], ['Central America', 'United States Gulf Coast (especially Florida Panhandle)']]

# damages (USD($)) of hurricanes
damages = ['Damages not recorded', '100M', 'Damages not recorded', '40M', '27.9M', '5M', 'Damages not recorded', '306M', '2M', '65.8M', '326M', '60.3M', '208M', '1.42B', '25.4M', 'Damages not recorded', '1.54B', '1.24B', '7.1B', '10B', '26.5B', '6.2B', '5.37B', '23.3B', '1.01B', '125B', '12B', '29.4B', '1.76B', '720M', '15.1B', '64.8B', '91.6B', '25.1B']

# deaths for each hurricane
deaths = [90,4000,16,3103,179,184,408,682,5,1023,43,319,688,259,37,11,2068,269,318,107,65,19325,51,124,17,1836,125,87,45,133,603,138,3057,74]

# {"Cuba I": {'Name': 'Cuba I', 'Month': 'October', 'Year': 1924, 'Max Sustained Wind': 165, 'Areas Affected': ['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], 'Damage': 'Damages not recorded', 'Deaths': 90}}.

# %%
## Project Goals:
# Write several functions that organize and manipulate data about Category 5 Hurricanes, the strongest hurricanes as rated by their wind speed.
# Each one of these functions will use a number of parameters, conditionals, lists, dictionaries, string manipulation, and return statements.

## Update damages function:
def update_damages(lst_of_damages):
    updated_damages = []
    for cost in lst_of_damages:
        if cost == 'Damages not recorded':
            updated_damages.append(cost)
        elif cost[-1] == 'M':
            updated_damages.append(float(cost[:-1])*(10**6))
        elif cost[-1] == 'B':
            updated_damages.append(float(cost[:-1])*(10**9))                              
        else:
            print('This value cannot be converted')
            pass
    return updated_damages
update_damages_var = update_damages(damages)


## Construct hurricane dictionary out of each lists, function:
def lists_to_dictionnary(names, months, years, max_sustained_winds, areas_affected, damages, deaths):
    hurricanes_names_dict = {}  
    for i in range(len(names)):
        hurricanes_names_dict[names[i]] = {'Name': names[i], 'Month': months[i], 'Year': years[i], 'Max Sustained Wind': max_sustained_winds[i], 'Areas Affected': areas_affected[i], 'Damage': damages[i], 'Deaths': deaths[i]}
    return hurricanes_names_dict
dict_hurricanes_var = lists_to_dictionnary(names, months, years, max_sustained_winds, areas_affected, damages, deaths)


## Construct hurricane dictionary by year out of hurricanes_names_dict, function:
# Function creating the dictionnary directly from lists_to_dictionnary function
def hurricanes_conv_per_year(dict_hurricanes_var):
    hurricanes_year_dict = {}   
    for i in range(len(dict_hurricanes_var)):
        hurricanes_records = [{'Name': names[i], 'Month': months[i], 'Year': years[i], 'Max Sustained Wind': max_sustained_winds[i], 'Areas Affected': areas_affected[i], 'Damage': damages[i], 'Deaths': deaths[i]}]
        if years[i] not in hurricanes_year_dict.keys():
            hurricanes_year_dict[years[i]] = hurricanes_records
        else:
            hurricanes_year_dict[years[i]].extend(hurricanes_records)      
    return hurricanes_year_dict
dict_hurricanes_conv_per_year = hurricanes_conv_per_year(dict_hurricanes_var)

# Function creating the dictionnary directly from each individual lists
# def hurricanes_names_to_year(names, months, years, max_sustained_winds, areas_affected, damages, deaths):
    # hurricanes_year_dict = {}
    # for i in range(len(names)):
    #     hurricanes_records = [{'Name': names[i], 'Month': months[i], 'Year': years[i], 'Max Sustained Wind': max_sustained_winds[i], 'Areas Affected': areas_affected[i], 'Damage': damages[i], 'Deaths': deaths[i]}]
    #     if years[i] not in hurricanes_year_dict.keys():
    #         hurricanes_year_dict[years[i]] = hurricanes_records
    #     else:
    #         hurricanes_year_dict[years[i]].extend(hurricanes_records)
    # return hurricanes_year_dict
# dict_hurricanes_names_to_year = hurricanes_names_to_year(names, months, years, max_sustained_winds, areas_affected, damages, deaths)


## Function counting how often areas are affected by hurricanes:
def count_affected_areas(areas_list):
    affected_areas_count = {} 
    for group in areas_list:
        for area in group:
            if area not in affected_areas_count.keys():
                affected_areas_count[area] = 1
            else:
                affected_areas_count[area] += 1
    return affected_areas_count
dict_count_affected_areas = count_affected_areas(areas_affected)


## Function finding the most affected area:
def most_affected_area(dict_count_affected_areas):
    max_area = ''
    max_area_count = 0   
    for area, count in dict_count_affected_areas.items():
        if count > max_area_count:
            max_area = area
            max_area_count = count
        else:
            continue   
    return '{area} is the most affected area with a total of {count} hurricanes'.format(area=max_area, count=max_area_count)
most_affected_area_var = most_affected_area(dict_count_affected_areas)


## Function finding the greatest number of deaths per hurricane:
def greatest_num_death(dict_hurricanes_var):
    max_mortality_cane = ''
    max_mortality = 0  
    for k, v in dict_hurricanes_var.items():
        if v.get('Deaths') > max_mortality:
            max_mortality = v.get('Deaths')
            max_mortality_cane = k
        else:
            continue      
    return '{name} had the most impact on populations with a total of {count} deaths'.format(name=max_mortality_cane, count=max_mortality)
greatest_num_death_var = greatest_num_death(dict_hurricanes_var)


## Function catgeorizing by mortality:
def categorize_by_mortality(dict_hurricanes_var):
    hurricanes_by_mortality = {}
    mortality_scale = {0: 0,
                    1: 100,
                    2: 500,
                    3: 1000,
                    4: 10000}   
    # Generate an empty dictionnary base on mortality_scale keys and with list for values
    for key in mortality_scale.keys():
        hurricanes_by_mortality[key] = []    
    # Test every death toll against the mortality scale dict
    for v in dict_hurricanes_var.values():
        low_scale_index = 0
        high_scale_index = 1   
        mortality_value = v.get('Deaths')                  
        for s, m in mortality_scale.items():           
            if mortality_scale[low_scale_index] <= mortality_value <= mortality_scale[high_scale_index]:               
                hurricanes_by_mortality[low_scale_index].append(v)
                break
            elif mortality_value >= mortality_scale[4]:         
                hurricanes_by_mortality[4].append(v)
                break
            else:
                if high_scale_index == 4:
                    low_scale_index += 1
                else:
                    low_scale_index += 1
                    high_scale_index += 1
    return hurricanes_by_mortality
categorize_by_mortality_var = categorize_by_mortality(dict_hurricanes_var)

# %%
# write your greatest damage function here:


# write your catgeorize by damage function here:
